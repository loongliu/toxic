# %%
import data_source
import model
import log
import train
import keras

log.init_log()

embed_file = 'data/glove.6B/glove.6B.100d.txt'

toxic_data = data_source.DataSource(embed_file, 100)

print(toxic_data.description())

# print(1)
#
# train_model = model.Lstm(toxic_data)
#
# train.train(train_model)
#
# print(2)


filepath = 'models/2018-01-23 17:07:19.278381/LSTM modelepoch: 4 val_loss 0.04920.hdf5'

keras.models.load_model(filepath)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 2018-01-23 17:31:51.392671: read train data: data/train_clean.csv and test data: data/test_clean.csv
# 2018-01-23 17:31:53.720989: train_sentences.shape (159571,)
# 2018-01-23 17:31:53.721657: test_sentences.shape (153164,)
# 2018-01-23 17:31:53.721700: y_train.shape (159571, 6)
# 2018-01-23 17:31:53.721725: tokenzie sentence from train and test
# 2018-01-23 17:32:41.217506: read embedding file data/glove.6B/glove.6B.100d.txt
# 2018-01-23 17:33:03.360113: found 329535 words in data, 120673 words in embedding
# 2018-01-23 17:33:03.686480: model use train data: data/train_clean.csv
# ...

# %%
toxic_model = keras.models.load_model(filepath)

# %%
y_test = toxic_model.predict([toxic_data.x_test], batch_size=1024, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0e3737b917c2> in <module>()
# ----> 1 y_test = toxic_model.predict([toxic_data.x_test], batch_size=1024, verbose=1)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1798         f = self.predict_function
#    1799         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1800                                   verbose=verbose, steps=steps)
#    1801
#    1802     def train_on_batch(self, x, y,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1299                     ins_batch[i] = ins_batch[i].toarray()
#    1300
# -> 1301                 batch_outs = f(ins_batch)
# ...
